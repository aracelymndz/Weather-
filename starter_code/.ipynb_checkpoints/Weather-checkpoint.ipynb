# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os 
import openweathermapy.core as owm
from pprint import pprint


#import api_keys
#from api_keys import api_key 

api_key = "9ed0108bc10b05aa2bf0d5077ffa4756" 
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# len(cities)

len(cities)
# Out:
# 635

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q=darhan"
wheat_response = requests.get(query_url)
wheather_json = wheat_response.json()
wheather_json
# Out:
# {'coord': {'lon': 105.92, 'lat': 49.49},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 1.27,
#   'pressure': 1023.08,
#   'humidity': 52,
#   'temp_min': 1.27,
#   'temp_max': 1.27,
#   'sea_level': 1023.08,
#   'grnd_level': 909.27},
#  'wind': {'speed': 3.72, 'deg': 42.5015},
#  'clouds': {'all': 64},
#  'dt': 1554350720,
#  'sys': {'message': 0.004,
#   'country': 'MN',
#   'sunrise': 1554330503,
#   'sunset': 1554377415},
#  'id': 2031964,
#  'name': 'Darhan',
#  'cod': 200}

# %%
# set up lists to hold reponse info
items = data("id", cities)
# Loop through the list of cities and perform a request for data on each

for city in cities:
#   print(query_url + city)
    response = requests.get(query_url + city).json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5fe979e6c8e5> in <module>
#       1 # set up lists to hold reponse info
# ----> 2 items = data("id", cities)
#       3 # Loop through the list of cities and perform a request for data on each
#       4
#       5 for city in cities:
#
# NameError: name 'data' is not defined

# %%
city = []
cloud = []
countr = []
date = []
humidity = []
Lat = []
lng = []
Max_Temp = []
Wind_Speed = []

for index in row
            city.append(weather_json['name'])
            cloud.append(weather_json['clouds']['all'])
            countr.append(weather_json['sys']['country'])
            date.append(weather_json['dt'])
            humidity.append(weather_json['main']['humidity'])
            Lat.append(weather_json['coord']['lat'])
            lng.append(weather_json['coord']['lon'])
            Max_Temp.append(weather_json['main']['temp_max'])
            Wind_Speed.append(weather_json['wind']['speed'])



df.dATAfRAME({})
# Out:
#   File "<ipython-input-14-8b3d515813a0>", line 11
#     for index in row
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
row_count = 1
print("Beginning Data Retrieval")
print("----------------------------")
for x in cities:
    print(f"Processing Record {row_count} {} of Set | {x}")
    row_count += 1
    
print("----------------------------") 
print("Data Retrieval Complet")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set | olafsvik
# Processing Record 2 of Set | general pico
# Processing Record 3 of Set | khatanga
# Processing Record 4 of Set | port elizabeth
# Processing Record 5 of Set | sao filipe
# Processing Record 6 of Set | henties bay
# Processing Record 7 of Set | vanimo
# Processing Record 8 of Set | albany
# Processing Record 9 of Set | acapulco
# Processing Record 10 of Set | pevek
# Processing Record 11 of Set | busselton
# Processing Record 12 of Set | cape town
# Processing Record 13 of Set | punta arenas
# Processing Record 14 of Set | rikitea
# Processing Record 15 of Set | simpang empat
# Processing Record 16 of Set | puerto ayora
# Processing Record 17 of Set | wanning
# Processing Record 18 of Set | mataura
# Processing Record 19 of Set | iqaluit
# Processing Record 20 of Set | san patricio
# Processing Record 21 of Set | airai
# Processing Record 22 of Set | sapao
# Processing Record 23 of Set | coquimbo
# Processing Record 24 of Set | katsuura
# Processing Record 25 of Set | carnarvon
# Processing Record 26 of Set | jamestown
# Processing Record 27 of Set | bredasdorp
# Processing Record 28 of Set | kununurra
# Processing Record 29 of Set | deep river
# Processing Record 30 of Set | marcona
# Processing Record 31 of Set | port macquarie
# Processing Record 32 of Set | lebu
# Processing Record 33 of Set | thompson
# Processing Record 34 of Set | makubetsu
# Processing Record 35 of Set | mulchen
# Processing Record 36 of Set | labuhan
# Processing Record 37 of Set | butaritari
# Processing Record 38 of Set | hami
# Processing Record 39 of Set | razdolnoye
# Processing Record 40 of Set | lompoc
# Processing Record 41 of Set | la peca
# Processing Record 42 of Set | san gabriel
# Processing Record 43 of Set | castro
# Processing Record 44 of Set | hualmay
# Processing Record 45 of Set | port alfred
# Processing Record 46 of Set | munsingen
# Processing Record 47 of Set | ushuaia
# Processing Record 48 of Set | cidreira
# Processing Record 49 of Set | ancud
# Processing Record 50 of Set | shelburne
# Processing Record 51 of Set | wahran
# Processing Record 52 of Set | tasiilaq
# Processing Record 53 of Set | saskylakh
# Processing Record 54 of Set | zhongshu
# Processing Record 55 of Set | bathsheba
# Processing Record 56 of Set | le vauclin
# Processing Record 57 of Set | poyarkovo
# Processing Record 58 of Set | longyearbyen
# Processing Record 59 of Set | ostersund
# Processing Record 60 of Set | arman
# Processing Record 61 of Set | ahipara
# Processing Record 62 of Set | bambous virieux
# Processing Record 63 of Set | hithadhoo
# Processing Record 64 of Set | puerto colombia
# Processing Record 65 of Set | cazaje
# Processing Record 66 of Set | tabas
# Processing Record 67 of Set | paso de carrasco
# Processing Record 68 of Set | boddam
# Processing Record 69 of Set | eenhana
# Processing Record 70 of Set | kidal
# Processing Record 71 of Set | comodoro rivadavia
# Processing Record 72 of Set | amguri
# Processing Record 73 of Set | georgetown
# Processing Record 74 of Set | kaitangata
# Processing Record 75 of Set | yellowknife
# Processing Record 76 of Set | atuona
# Processing Record 77 of Set | asau
# Processing Record 78 of Set | taolanaro
# Processing Record 79 of Set | lerwick
# Processing Record 80 of Set | illoqqortoormiut
# Processing Record 81 of Set | mullaitivu
# Processing Record 82 of Set | vao
# Processing Record 83 of Set | touros
# Processing Record 84 of Set | elat
# Processing Record 85 of Set | torbay
# Processing Record 86 of Set | qaanaaq
# Processing Record 87 of Set | hilo
# Processing Record 88 of Set | bluff
# Processing Record 89 of Set | hobart
# Processing Record 90 of Set | vardo
# Processing Record 91 of Set | los llanos de aridane
# Processing Record 92 of Set | nguruka
# Processing Record 93 of Set | clyde river
# Processing Record 94 of Set | humaita
# Processing Record 95 of Set | victoria
# Processing Record 96 of Set | batsfjord
# Processing Record 97 of Set | codrington
# Processing Record 98 of Set | bermejo
# Processing Record 99 of Set | avarua
# Processing Record 100 of Set | nikolskoye
# Processing Record 101 of Set | ribeira grande
# Processing Record 102 of Set | tulnici
# Processing Record 103 of Set | kamenka
# Processing Record 104 of Set | nakapiripirit
# Processing Record 105 of Set | barrow
# Processing Record 106 of Set | new norfolk
# Processing Record 107 of Set | khani
# Processing Record 108 of Set | rawannawi
# Processing Record 109 of Set | cayenne
# Processing Record 110 of Set | blackfoot
# Processing Record 111 of Set | kapaa
# Processing Record 112 of Set | upernavik
# Processing Record 113 of Set | luwuk
# Processing Record 114 of Set | vaini
# Processing Record 115 of Set | mar del plata
# Processing Record 116 of Set | harper
# Processing Record 117 of Set | kodiak
# Processing Record 118 of Set | whitehorse
# Processing Record 119 of Set | husavik
# Processing Record 120 of Set | isangel
# Processing Record 121 of Set | chuy
# Processing Record 122 of Set | mundo nuevo
# Processing Record 123 of Set | tiksi
# Processing Record 124 of Set | saint george
# Processing Record 125 of Set | gat
# Processing Record 126 of Set | hamilton
# Processing Record 127 of Set | aklavik
# Processing Record 128 of Set | beian
# Processing Record 129 of Set | palmas
# Processing Record 130 of Set | sentyabrskiy
# Processing Record 131 of Set | agadez
# Processing Record 132 of Set | barentsburg
# Processing Record 133 of Set | shetpe
# Processing Record 134 of Set | fortuna
# Processing Record 135 of Set | tautira
# Processing Record 136 of Set | bilibino
# Processing Record 137 of Set | klaksvik
# Processing Record 138 of Set | tamandare
# Processing Record 139 of Set | havoysund
# Processing Record 140 of Set | igarka
# Processing Record 141 of Set | chinchina
# Processing Record 142 of Set | wicklow
# Processing Record 143 of Set | falealupo
# Processing Record 144 of Set | sorland
# Processing Record 145 of Set | koraput
# Processing Record 146 of Set | itarema
# Processing Record 147 of Set | grand gaube
# Processing Record 148 of Set | sri aman
# Processing Record 149 of Set | rupert
# Processing Record 150 of Set | mys shmidta
# Processing Record 151 of Set | cabo san lucas
# Processing Record 152 of Set | bone
# Processing Record 153 of Set | jagdalpur
# Processing Record 154 of Set | salinas
# Processing Record 155 of Set | cherskiy
# Processing Record 156 of Set | roura
# Processing Record 157 of Set | amderma
# Processing Record 158 of Set | narsaq
# Processing Record 159 of Set | nizhneyansk
# Processing Record 160 of Set | pisco
# Processing Record 161 of Set | east london
# Processing Record 162 of Set | kavieng
# Processing Record 163 of Set | provideniya
# Processing Record 164 of Set | kloulklubed
# Processing Record 165 of Set | abu dhabi
# Processing Record 166 of Set | coolum beach
# Processing Record 167 of Set | tuktoyaktuk
# Processing Record 168 of Set | xiamen
# Processing Record 169 of Set | stokmarknes
# Processing Record 170 of Set | belushya guba
# Processing Record 171 of Set | dunedin
# Processing Record 172 of Set | vaitupu
# Processing Record 173 of Set | dikson
# Processing Record 174 of Set | craig
# Processing Record 175 of Set | wajima
# Processing Record 176 of Set | urucara
# Processing Record 177 of Set | sitka
# Processing Record 178 of Set | luhyny
# Processing Record 179 of Set | ridgecrest
# Processing Record 180 of Set | chokurdakh
# Processing Record 181 of Set | halalo
# Processing Record 182 of Set | hasaki
# Processing Record 183 of Set | hermosillo
# Processing Record 184 of Set | hermanus
# Processing Record 185 of Set | mount gambier
# Processing Record 186 of Set | santa isabel do rio negro
# Processing Record 187 of Set | back mountain
# Processing Record 188 of Set | ginda
# Processing Record 189 of Set | broken hill
# Processing Record 190 of Set | baracatan
# Processing Record 191 of Set | hofn
# Processing Record 192 of Set | zhangjiakou
# Processing Record 193 of Set | manokwari
# Processing Record 194 of Set | puerto del rosario
# Processing Record 195 of Set | winnemucca
# Processing Record 196 of Set | kieta
# Processing Record 197 of Set | bereda
# Processing Record 198 of Set | leningradskiy
# Processing Record 199 of Set | dumai
# Processing Record 200 of Set | caravelas
# Processing Record 201 of Set | lorengau
# Processing Record 202 of Set | bozoum
# Processing Record 203 of Set | yerbogachen
# Processing Record 204 of Set | rantauprapat
# Processing Record 205 of Set | tricase
# Processing Record 206 of Set | chimbote
# Processing Record 207 of Set | chernyshevskiy
# Processing Record 208 of Set | artyk
# Processing Record 209 of Set | macas
# Processing Record 210 of Set | bambanglipuro
# Processing Record 211 of Set | kamenskoye
# Processing Record 212 of Set | saint-georges
# Processing Record 213 of Set | anadyr
# Processing Record 214 of Set | adrar
# Processing Record 215 of Set | petropavlovsk-kamchatskiy
# Processing Record 216 of Set | mahon
# Processing Record 217 of Set | hudiksvall
# Processing Record 218 of Set | namatanai
# Processing Record 219 of Set | zavodouspenskoye
# Processing Record 220 of Set | bogorodskoye
# Processing Record 221 of Set | vaitape
# Processing Record 222 of Set | kisangani
# Processing Record 223 of Set | acajutla
# Processing Record 224 of Set | eureka
# Processing Record 225 of Set | deputatskiy
# Processing Record 226 of Set | mocuba
# Processing Record 227 of Set | samusu
# Processing Record 228 of Set | sainte-anne-des-monts
# Processing Record 229 of Set | samalaeulu
# Processing Record 230 of Set | la ronge
# Processing Record 231 of Set | saint stephen
# Processing Record 232 of Set | honiara
# Processing Record 233 of Set | palabuhanratu
# Processing Record 234 of Set | severo-kurilsk
# Processing Record 235 of Set | cedar city
# Processing Record 236 of Set | pangnirtung
# Processing Record 237 of Set | sao joao de pirabas
# Processing Record 238 of Set | bongandanga
# Processing Record 239 of Set | ascension
# Processing Record 240 of Set | xai-xai
# Processing Record 241 of Set | lethem
# Processing Record 242 of Set | dhidhdhoo
# Processing Record 243 of Set | vagur
# Processing Record 244 of Set | acari
# Processing Record 245 of Set | port-gentil
# Processing Record 246 of Set | constitucion
# Processing Record 247 of Set | geraldton
# Processing Record 248 of Set | alberton
# Processing Record 249 of Set | juifang
# Processing Record 250 of Set | amboasary
# Processing Record 251 of Set | praia da vitoria
# Processing Record 252 of Set | bhindar
# Processing Record 253 of Set | poum
# Processing Record 254 of Set | wairoa
# Processing Record 255 of Set | lata
# Processing Record 256 of Set | yerofey pavlovich
# Processing Record 257 of Set | ust-barguzin
# Processing Record 258 of Set | siniscola
# Processing Record 259 of Set | kendal
# Processing Record 260 of Set | kahului
# Processing Record 261 of Set | roald
# Processing Record 262 of Set | shache
# Processing Record 263 of Set | jalu
# Processing Record 264 of Set | inta
# Processing Record 265 of Set | rantepao
# Processing Record 266 of Set | rawson
# Processing Record 267 of Set | pincher creek
# Processing Record 268 of Set | ilulissat
# Processing Record 269 of Set | chicama
# Processing Record 270 of Set | bluefields
# Processing Record 271 of Set | nuevo progreso
# Processing Record 272 of Set | kutum
# Processing Record 273 of Set | beringovskiy
# Processing Record 274 of Set | ormara
# Processing Record 275 of Set | epe
# Processing Record 276 of Set | faanui
# Processing Record 277 of Set | yaan
# Processing Record 278 of Set | pandan
# Processing Record 279 of Set | arraial do cabo
# Processing Record 280 of Set | elko
# Processing Record 281 of Set | yashkul
# Processing Record 282 of Set | roebourne
# Processing Record 283 of Set | okhotsk
# Processing Record 284 of Set | benguela
# Processing Record 285 of Set | norman wells
# Processing Record 286 of Set | kapoeta
# Processing Record 287 of Set | taft
# Processing Record 288 of Set | mahebourg
# Processing Record 289 of Set | port hardy
# Processing Record 290 of Set | marsabit
# Processing Record 291 of Set | kuche
# Processing Record 292 of Set | mata grande
# Processing Record 293 of Set | jiaocheng
# Processing Record 294 of Set | bosobolo
# Processing Record 295 of Set | alofi
# Processing Record 296 of Set | calama
# Processing Record 297 of Set | yelovo
# Processing Record 298 of Set | nome
# Processing Record 299 of Set | burns lake
# Processing Record 300 of Set | yunjinghong
# Processing Record 301 of Set | berlevag
# Processing Record 302 of Set | giyon
# Processing Record 303 of Set | chegdomyn
# Processing Record 304 of Set | kapit
# Processing Record 305 of Set | luderitz
# Processing Record 306 of Set | kismayo
# Processing Record 307 of Set | ketchikan
# Processing Record 308 of Set | kaeo
# Processing Record 309 of Set | dingle
# Processing Record 310 of Set | saint anthony
# Processing Record 311 of Set | vestmanna
# Processing Record 312 of Set | westport
# Processing Record 313 of Set | tuatapere
# Processing Record 314 of Set | powell
# Processing Record 315 of Set | tsihombe
# Processing Record 316 of Set | bera
# Processing Record 317 of Set | balakhta
# Processing Record 318 of Set | soyo
# Processing Record 319 of Set | morondava
# Processing Record 320 of Set | nantucket
# Processing Record 321 of Set | bengkulu
# Processing Record 322 of Set | baixo guandu
# Processing Record 323 of Set | garissa
# Processing Record 324 of Set | saint-philippe
# Processing Record 325 of Set | ballina
# Processing Record 326 of Set | yantzaza
# Processing Record 327 of Set | nisia floresta
# Processing Record 328 of Set | antsohihy
# Processing Record 329 of Set | mumford
# Processing Record 330 of Set | zharkent
# Processing Record 331 of Set | spassk-ryazanskiy
# Processing Record 332 of Set | chinsali
# Processing Record 333 of Set | sao joao da barra
# Processing Record 334 of Set | conceicao do coite
# Processing Record 335 of Set | beloha
# Processing Record 336 of Set | lasa
# Processing Record 337 of Set | chulym
# Processing Record 338 of Set | astoria
# Processing Record 339 of Set | shingu
# Processing Record 340 of Set | chino valley
# Processing Record 341 of Set | tura
# Processing Record 342 of Set | kampene
# Processing Record 343 of Set | attawapiskat
# Processing Record 344 of Set | linxia
# Processing Record 345 of Set | bokspits
# Processing Record 346 of Set | the pas
# Processing Record 347 of Set | esperance
# Processing Record 348 of Set | baghdad
# Processing Record 349 of Set | aden
# Processing Record 350 of Set | mehamn
# Processing Record 351 of Set | namibe
# Processing Record 352 of Set | melendugno
# Processing Record 353 of Set | tumannyy
# Processing Record 354 of Set | durban
# Processing Record 355 of Set | gotsu
# Processing Record 356 of Set | maamba
# Processing Record 357 of Set | obigarm
# Processing Record 358 of Set | ekhabi
# Processing Record 359 of Set | bethel
# Processing Record 360 of Set | inhambane
# Processing Record 361 of Set | guerrero negro
# Processing Record 362 of Set | jinchengjiang
# Processing Record 363 of Set | atar
# Processing Record 364 of Set | loiza
# Processing Record 365 of Set | agadir
# Processing Record 366 of Set | talcahuano
# Processing Record 367 of Set | haines junction
# Processing Record 368 of Set | balsas
# Processing Record 369 of Set | dubrovnik
# Processing Record 370 of Set | suleya
# Processing Record 371 of Set | west wendover
# Processing Record 372 of Set | duz
# Processing Record 373 of Set | venice
# Processing Record 374 of Set | ponta do sol
# Processing Record 375 of Set | kungurtug
# Processing Record 376 of Set | ewa beach
# Processing Record 377 of Set | udachnyy
# Processing Record 378 of Set | pitimbu
# Processing Record 379 of Set | kamaishi
# Processing Record 380 of Set | houston
# Processing Record 381 of Set | vitimskiy
# Processing Record 382 of Set | san juan
# Processing Record 383 of Set | yumen
# Processing Record 384 of Set | tual
# Processing Record 385 of Set | broome
# Processing Record 386 of Set | caranavi
# Processing Record 387 of Set | zhezkazgan
# Processing Record 388 of Set | terra roxa
# Processing Record 389 of Set | fairbanks
# Processing Record 390 of Set | flinders
# Processing Record 391 of Set | yatou
# Processing Record 392 of Set | araci
# Processing Record 393 of Set | rocha
# Processing Record 394 of Set | pouebo
# Processing Record 395 of Set | nicoya
# Processing Record 396 of Set | urumqi
# Processing Record 397 of Set | vestmannaeyjar
# Processing Record 398 of Set | richards bay
# Processing Record 399 of Set | jiuquan
# Processing Record 400 of Set | umzimvubu
# Processing Record 401 of Set | vanavara
# Processing Record 402 of Set | sistranda
# Processing Record 403 of Set | nabire
# Processing Record 404 of Set | karasjok
# Processing Record 405 of Set | moose factory
# Processing Record 406 of Set | lagoa
# Processing Record 407 of Set | zachagansk
# Processing Record 408 of Set | puerto madryn
# Processing Record 409 of Set | hohhot
# Processing Record 410 of Set | sibu
# Processing Record 411 of Set | ciudad del maiz
# Processing Record 412 of Set | malakal
# Processing Record 413 of Set | doka
# Processing Record 414 of Set | lavrentiya
# Processing Record 415 of Set | oriximina
# Processing Record 416 of Set | yarega
# Processing Record 417 of Set | kindersley
# Processing Record 418 of Set | hirara
# Processing Record 419 of Set | auch
# Processing Record 420 of Set | palmerston north
# Processing Record 421 of Set | kalianget
# Processing Record 422 of Set | siderno
# Processing Record 423 of Set | belaya gora
# Processing Record 424 of Set | saleaula
# Processing Record 425 of Set | tall kayf
# Processing Record 426 of Set | bubaque
# Processing Record 427 of Set | salalah
# Processing Record 428 of Set | zaanstad
# Processing Record 429 of Set | paamiut
# Processing Record 430 of Set | puerto escondido
# Processing Record 431 of Set | batagay-alyta
# Processing Record 432 of Set | vyara
# Processing Record 433 of Set | chervishevo
# Processing Record 434 of Set | banswara
# Processing Record 435 of Set | kamariotissa
# Processing Record 436 of Set | papetoai
# Processing Record 437 of Set | vila
# Processing Record 438 of Set | komsomolskiy
# Processing Record 439 of Set | bandiagara
# Processing Record 440 of Set | porto novo
# Processing Record 441 of Set | korla
# Processing Record 442 of Set | antofagasta
# Processing Record 443 of Set | belgorod
# Processing Record 444 of Set | aitape
# Processing Record 445 of Set | manbij
# Processing Record 446 of Set | atengo
# Processing Record 447 of Set | ladwa
# Processing Record 448 of Set | sovetskiy
# Processing Record 449 of Set | mount isa
# Processing Record 450 of Set | barabai
# Processing Record 451 of Set | sunndalsora
# Processing Record 452 of Set | sokoni
# Processing Record 453 of Set | quatre cocos
# Processing Record 454 of Set | hurghada
# Processing Record 455 of Set | wewak
# Processing Record 456 of Set | mansa
# Processing Record 457 of Set | lolua
# Processing Record 458 of Set | semirom
# Processing Record 459 of Set | nanortalik
# Processing Record 460 of Set | saint peter
# Processing Record 461 of Set | kondinskoye
# Processing Record 462 of Set | whyalla
# Processing Record 463 of Set | merauke
# Processing Record 464 of Set | boende
# Processing Record 465 of Set | tabou
# Processing Record 466 of Set | keetmanshoop
# Processing Record 467 of Set | lolotique
# Processing Record 468 of Set | veraval
# Processing Record 469 of Set | maun
# Processing Record 470 of Set | solwezi
# Processing Record 471 of Set | olecko
# Processing Record 472 of Set | christchurch
# Processing Record 473 of Set | valentin gomez farias
# Processing Record 474 of Set | ulaangom
# Processing Record 475 of Set | seoul
# Processing Record 476 of Set | verkh-usugli
# Processing Record 477 of Set | kavaratti
# Processing Record 478 of Set | campo largo
# Processing Record 479 of Set | berdigestyakh
# Processing Record 480 of Set | evanston
# Processing Record 481 of Set | galveston
# Processing Record 482 of Set | toliary
# Processing Record 483 of Set | ust-maya
# Processing Record 484 of Set | brae
# Processing Record 485 of Set | half moon bay
# Processing Record 486 of Set | bulungu
# Processing Record 487 of Set | cururupu
# Processing Record 488 of Set | itaituba
# Processing Record 489 of Set | koutiala
# Processing Record 490 of Set | teul
# Processing Record 491 of Set | muros
# Processing Record 492 of Set | nortelandia
# Processing Record 493 of Set | boda
# Processing Record 494 of Set | naze
# Processing Record 495 of Set | meyungs
# Processing Record 496 of Set | pietersburg
# Processing Record 497 of Set | boralday
# Processing Record 498 of Set | ostrovnoy
# Processing Record 499 of Set | shambu
# Processing Record 500 of Set | buala
# Processing Record 501 of Set | mamallapuram
# Processing Record 502 of Set | tulum
# Processing Record 503 of Set | college
# Processing Record 504 of Set | padang
# Processing Record 505 of Set | chabahar
# Processing Record 506 of Set | dongsheng
# Processing Record 507 of Set | san policarpo
# Processing Record 508 of Set | abadiania
# Processing Record 509 of Set | souillac
# Processing Record 510 of Set | cookeville
# Processing Record 511 of Set | makakilo city
# Processing Record 512 of Set | melfi
# Processing Record 513 of Set | anito
# Processing Record 514 of Set | comandau
# Processing Record 515 of Set | kiruna
# Processing Record 516 of Set | alvorada
# Processing Record 517 of Set | aljezur
# Processing Record 518 of Set | toora-khem
# Processing Record 519 of Set | bocaiuva
# Processing Record 520 of Set | itupeva
# Processing Record 521 of Set | scottsburgh
# Processing Record 522 of Set | verkhnevilyuysk
# Processing Record 523 of Set | marovoay
# Processing Record 524 of Set | tambura
# Processing Record 525 of Set | port lincoln
# Processing Record 526 of Set | mayo
# Processing Record 527 of Set | saint-joseph
# Processing Record 528 of Set | kijang
# Processing Record 529 of Set | zhuhai
# Processing Record 530 of Set | sao jose da coroa grande
# Processing Record 531 of Set | cordoba
# Processing Record 532 of Set | edd
# Processing Record 533 of Set | malwan
# Processing Record 534 of Set | axim
# Processing Record 535 of Set | codo
# Processing Record 536 of Set | fort nelson
# Processing Record 537 of Set | viet tri
# Processing Record 538 of Set | paraiso
# Processing Record 539 of Set | marathon
# Processing Record 540 of Set | campoverde
# Processing Record 541 of Set | bireun
# Processing Record 542 of Set | andselv
# Processing Record 543 of Set | havre-saint-pierre
# Processing Record 544 of Set | nguiu
# Processing Record 545 of Set | mesyagutovo
# Processing Record 546 of Set | sinazongwe
# Processing Record 547 of Set | gillette
# Processing Record 548 of Set | fevik
# Processing Record 549 of Set | shihezi
# Processing Record 550 of Set | qaqortoq
# Processing Record 551 of Set | ginir
# Processing Record 552 of Set | ahuas
# Processing Record 553 of Set | sao felix do xingu
# Processing Record 554 of Set | taltal
# Processing Record 555 of Set | kasra
# Processing Record 556 of Set | cockburn town
# Processing Record 557 of Set | madiun
# Processing Record 558 of Set | bad bentheim
# Processing Record 559 of Set | bozhou
# Processing Record 560 of Set | rujewa
# Processing Record 561 of Set | noumea
# Processing Record 562 of Set | salem
# Processing Record 563 of Set | fukue
# Processing Record 564 of Set | conde
# Processing Record 565 of Set | ondorhaan
# Processing Record 566 of Set | ler
# Processing Record 567 of Set | dunmore town
# Processing Record 568 of Set | hihifo
# Processing Record 569 of Set | pacific grove
# Processing Record 570 of Set | laguna
# Processing Record 571 of Set | manuk mangkaw
# Processing Record 572 of Set | peniche
# Processing Record 573 of Set | north bend
# Processing Record 574 of Set | malacacheta
# Processing Record 575 of Set | barbar
# Processing Record 576 of Set | narasannapeta
# Processing Record 577 of Set | rochelle
# Processing Record 578 of Set | marsaxlokk
# Processing Record 579 of Set | shimoda
# Processing Record 580 of Set | olga
# Processing Record 581 of Set | moron
# Processing Record 582 of Set | karoi
# Processing Record 583 of Set | pimentel
# Processing Record 584 of Set | fort morgan
# Processing Record 585 of Set | north platte
# Processing Record 586 of Set | toungoo
# Processing Record 587 of Set | marzuq
# Processing Record 588 of Set | suksun
# Processing Record 589 of Set | scarborough
# Processing Record 590 of Set | dagda
# Processing Record 591 of Set | mantua
# Processing Record 592 of Set | luanda
# Processing Record 593 of Set | popondetta
# Processing Record 594 of Set | karaul
# Processing Record 595 of Set | nadym
# Processing Record 596 of Set | manaure
# Processing Record 597 of Set | zhangzhou
# Processing Record 598 of Set | cabinda
# Processing Record 599 of Set | amga
# Processing Record 600 of Set | griffith
# Processing Record 601 of Set | puerto penasco
# Processing Record 602 of Set | mugla
# Processing Record 603 of Set | alta floresta
# Processing Record 604 of Set | grand river south east
# Processing Record 605 of Set | gimli
# Processing Record 606 of Set | skovde
# Processing Record 607 of Set | meulaboh
# Processing Record 608 of Set | plettenberg bay
# Processing Record 609 of Set | inuvik
# Processing Record 610 of Set | rio gallegos
# ----------------------------
# Data Retrieval Complet
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
